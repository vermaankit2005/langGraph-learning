# %% [markdown]
# <a href="https://colab.research.google.com/github/vermaankit2005/langGraph-learning/blob/main/LangGraph_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hi
